# %% [markdown]
# We are go to extract feature from query image and all the image in the base.
#
# we will calculate entropy, roberts, sobel, gabor and average value of all pixal.
#
# Feature from every image in the input folder are captured in a hdf5 file.

# %%
import numpy as np 
import os
from skimage.transform import resize
from skimage import io, img_as_ubyte
import h5py
from skimage.filters import roberts, sobel
from skimage.color import rgb2lab, rgb2gray
import cv2
from skimage.filters.rank import entropy
from skimage.morphology import disk
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def extract_features(image):
    #extracts color features
    lab_image = rgb2lab(image)
    A_image = lab_image[:,:,1]
    A_feat = A_image.mean()
    B_image = lab_image[:,:,2]
    B_feat = B_image.mean()

    #extracts textural features on the gray image
    gray_image = rgb2gray(image)
    gray_image = resize(gray_image, (256,256))
    gray_image = img_as_ubyte(gray_image)

    #entropy
    entropy_image = entropy(gray_image, disk(3))
    entropy_mean = entropy_image.mean()
    entropy_std = entropy_image.std()
    roberts_image = roberts(gray_image)
    robert_mean = roberts_image.mean()
    sobel_image = sobel(gray_image)
    sobel_mean = sobel_image.mean()

    #Gabor1
    kernel1 = cv2.getGaborKernel((9, 9), 3, np.pi/4, np.pi, 0.5, 0, ktype=cv2.CV_32F)
    gabor1 = (cv2.filter2D(gray_image, cv2.CV_8UC3, kernel1)).mean()

    #Gabor 2
    kernel2 = cv2.getGaborKernel((9, 9), 3, np.pi/2, np.pi/4, 0.9, 0, ktype=cv2.CV_32F)
    gabor2 = (cv2.filter2D(gray_image, cv2.CV_8UC3, kernel2)).mean()

    #Gabor 3
    kernel3 = cv2.getGaborKernel((9, 9), 5, np.pi/2, np.pi/2, 0.1, 0, ktype=cv2.CV_32F)
    gabor3 = (cv2.filter2D(gray_image, cv2.CV_8UC3, kernel3)).mean()
    custom_features = np.array([A_feat, B_feat, entropy_mean, entropy_std, robert_mean, sobel_mean, gabor1, gabor2, gabor3])

    return custom_features

if __name__ == "__main__":
    path = "/Users/sudipkhadka/Desktop/Data-Science-ML-Engineering/Image-Reterival-System/images/"

    feats = []
    names = []

    for img in os.listdir(path):
        print("Extracting features from image: ", img)
        #image = io.imread(path+img)
        image = io.imread(os.path.join(path, img))

        X = extract_features(image)
        feats.append(X)
        names.append(img)
    feats = np.array(feats)
    feature_file = "CustomFeatures.h5"
    print("Saving features to h5 file")

    h5f = h5py.File(feature_file, "w")
    h5f.create_dataset('dataset_1', data = feats)
    h5f.create_dataset('dataset_2', data = np.string_(names))
    h5f.close()
# Out:
# Extracting features from image:  50eff9bc37.jpg
# Extracting features from image:  69f7798bf6.jpg
# Extracting features from image:  3acb463808.jpg
# Extracting features from image:  232c360323.jpg
# Extracting features from image:  9a5f7038d8.jpg
# Extracting features from image:  361e677a43.jpg
# Extracting features from image:  2c29b90106.jpg
# Extracting features from image:  9d3f4d761f.jpg
# Extracting features from image:  2c1cc913aa.jpg
# Extracting features from image:  451ea62851.jpg
# Extracting features from image:  9bc9697203.jpg
# Extracting features from image:  0dc9f0e83d.jpg
# Extracting features from image:  098c4da6d0.jpg
# Extracting features from image:  3be2445a1d.jpg
# Extracting features from image:  3d64a8f546.jpg
# Extracting features from image:  128fc39904.jpg
# Extracting features from image:  90af12d313.jpg
# Extracting features from image:  31a15fab2e.jpg
# Extracting features from image:  509a68ebcd.jpg
# Extracting features from image:  95b2af165f.jpg
# Extracting features from image:  3f4255720e.jpg
# Extracting features from image:  7e29f317b0.jpg
# Extracting features from image:  3eb1842a09.jpg
# Extracting features from image:  92ec6a9100.jpg
# Extracting features from image:  2d3ddffc1e.jpg
# Extracting features from image:  14f4ea409d.jpg
# Extracting features from image:  4fa927ae7c.jpg
# Extracting features from image:  0409cd9133.jpg
# Extracting features from image:  1ae720ad3b.jpg
# Extracting features from image:  004c3aef03.jpg
# Extracting features from image:  39ec92a6f7.jpg
# Extracting features from image:  37a8b91ac8.jpg
# Extracting features from image:  3ecb859180.jpg
# Extracting features from image:  068da2429f.jpg
# Extracting features from image:  97bdca28af.jpg
# Extracting features from image:  2a83af58b0.jpg
# Extracting features from image:  30e10509da.jpg
# Extracting features from image:  0bb606e8b2.jpg
# Extracting features from image:  099fbe0054.jpg
# Extracting features from image:  7b295aebeb.jpg
# Extracting features from image:  3d87057258.jpg
# Extracting features from image:  84b0988e72.jpg
# Extracting features from image:  369c4bfa7c.jpg
# Extracting features from image:  230d4f00d3.jpg
# Extracting features from image:  0ff564b311.jpg
# Extracting features from image:  3d7670d847.jpg
# Extracting features from image:  030b91da73.jpg
# Extracting features from image:  0ace398f01.jpg
# Extracting features from image:  3df89aa7cd.jpg
# Extracting features from image:  28cd511ba8.jpg
# Extracting features from image:  4f21ad4aa0.jpg
# Extracting features from image:  36f0afcd07.jpg
# Extracting features from image:  3a95b92996.jpg
# Extracting features from image:  0dfef44672.jpg
# Extracting features from image:  7be95d405b.jpg
# Extracting features from image:  22e9010257.jpg
# Extracting features from image:  9f69ab6d45.jpg
# Extracting features from image:  63f4062ea7.jpg
# Extracting features from image:  2e7b3347db.jpg
# Extracting features from image:  92b4266d7b.jpg
# Extracting features from image:  39d54d730b.jpg
# Extracting features from image:  8776f48a39.jpg
# Extracting features from image:  2e6ccbf085.jpg
# Extracting features from image:  7f04fab8df.jpg
# Extracting features from image:  408bb4a1d3.jpg
# Extracting features from image:  9d13cf4d60.jpg
# Extracting features from image:  9cefc03068.jpg
# Extracting features from image:  5cf859bbf4.jpg
# Extracting features from image:  05ff493297.jpg
# Extracting features from image:  98f084e404.jpg
# Extracting features from image:  6ce77ef8d2.jpg
# Extracting features from image:  8f421fb06f.jpg
# Extracting features from image:  18eaaca1b0.jpg
# Extracting features from image:  07a65ded77.jpg
# Extracting features from image:  928bda9343.jpg
# Extracting features from image:  85ebd9b6f4.jpg
# Extracting features from image:  99c9f83443.jpg
# Extracting features from image:  185e168504.jpg
# Extracting features from image:  91a189eafa.jpg
# Extracting features from image:  4f33c939db.jpg
# Extracting features from image:  1e4417e510.jpg
# Extracting features from image:  81f495ab7d.jpg
# Extracting features from image:  8a6c9e28e6.jpg
# Extracting features from image:  2d3df39114.jpg
# Extracting features from image:  8acaacc7a7.jpg
# Extracting features from image:  68087b595a.jpg
# Extracting features from image:  7ea35b2c27.jpg
# Extracting features from image:  8dc75d04ac.jpg
# Extracting features from image:  18bf90ba80.jpg
# Extracting features from image:  074ad5a1e6.jpg
# Extracting features from image:  98d7112d0f.jpg
# Extracting features from image:  4c1e6cd5bb.jpg
# Extracting features from image:  5ec3b8303a.jpg
# Extracting features from image:  140e11d384.jpg
# Extracting features from image:  3a263f15d6.jpg
# Extracting features from image:  7fad63ba1e.jpg
# Extracting features from image:  7d4b463567.jpg
# Extracting features from image:  99a28cfab0.jpg
# Extracting features from image:  3a8fc5e677.jpg
# Extracting features from image:  67ab4295db.jpg
# Extracting features from image:  08e4894318.jpg
# Extracting features from image:  78e9d78309.jpg
# Extracting features from image:  52a09a1989.jpg
# Extracting features from image:  32c3dcf316.jpg
# Extracting features from image:  7b58c86003.jpg
# Extracting features from image:  4c357a6907.jpg
# Extracting features from image:  2defbeec7d.jpg
# Extracting features from image:  33ba6bd581.jpg
# Extracting features from image:  33d985771f.jpg
# Extracting features from image:  3e7a900953.jpg
# Extracting features from image:  82b0cab95a.jpg
# Extracting features from image:  4ebd97228c.jpg
# Extracting features from image:  4c5d959626.jpg
# Extracting features from image:  066fdf665a.jpg
# Extracting features from image:  9d6b3cc936.jpg
# Extracting features from image:  88ce8d773f.jpg
# Extracting features from image:  61a01da7a5.jpg
# Extracting features from image:  987aa8b95e.jpg
# Extracting features from image:  532f20fef7.jpg
# Extracting features from image:  3f2fba956b.jpg
# Extracting features from image:  92beefc18b.jpg
# Extracting features from image:  46d2138807.jpg
# Extracting features from image:  3a768f9814.jpg
# Extracting features from image:  6a47498208.jpg
# Extracting features from image:  76cbdee97d.jpg
# Extracting features from image:  4dd710bf1d.jpg
# Extracting features from image:  0058a88ed6.jpg
# Extracting features from image:  8a217ccfd1.jpg
# Extracting features from image:  42ce2a0e8c.jpg
# Extracting features from image:  12f051134a.jpg
# Extracting features from image:  96decfc0ff.jpg
# Extracting features from image:  80f5e8d84a.jpg
# Extracting features from image:  82f107f486.jpg
# Extracting features from image:  2c68c0e54e.jpg
# Extracting features from image:  162fb4d62e.jpg
# Extracting features from image:  6d9a76149f.jpg
# Extracting features from image:  46beba7077.jpg
# Extracting features from image:  7de3f2ba74.jpg
# Extracting features from image:  1d0f37aa48.jpg
# Extracting features from image:  9d5e9db945.jpg
# Extracting features from image:  16bbc4b4dc.jpg
# Extracting features from image:  1f88532b75.jpg
# Extracting features from image:  9f1f10fc7b.jpg
# Extracting features from image:  30d3c289d7.jpg
# Extracting features from image:  0a151f5c78.jpg
# Extracting features from image:  8cf5328886.jpg
# Extracting features from image:  8f89f4ac94.jpg
# Extracting features from image:  25f2fc1e5a.jpg
# Extracting features from image:  52ebd5c3a3.jpg
# Extracting features from image:  68e0a33dbf.jpg
# Extracting features from image:  3f8b153750.jpg
# Extracting features from image:  7eaec4d97b.jpg
# Extracting features from image:  5ccaa39d41.jpg
# Extracting features from image:  88bdf2941b.jpg
# Extracting features from image:  16f260ce97.jpg
# Extracting features from image:  5ecc7d9008.jpg
# Extracting features from image:  7e7669cc8a.jpg
# Extracting features from image:  5e722e5a91.jpg
# Extracting features from image:  2b3ff17004.jpg
# Extracting features from image:  5fd27b9fe5.jpg
# Extracting features from image:  23dcefd769.jpg
# Extracting features from image:  6e66339f51.jpg
# Extracting features from image:  0b1ae678e9.jpg
# Extracting features from image:  0efc08495b.jpg
# Extracting features from image:  64fd30d622.jpg
# Extracting features from image:  3f5c04a48c.jpg
# Extracting features from image:  491e05deef.jpg
# Extracting features from image:  7a9d8d9c66.jpg
# Extracting features from image:  8005f47721.jpg
# Extracting features from image:  8e5ebe9684.jpg
# Extracting features from image:  5b37e639d0.jpg
# Extracting features from image:  1cc23d3752.jpg
# Extracting features from image:  5b1b5f242b.jpg
# Extracting features from image:  1bdb6f9696.jpg
# Extracting features from image:  037bf28bc5.jpg
# Extracting features from image:  58dc8353c0.jpg
# Extracting features from image:  6eb6f765a0.jpg
# Extracting features from image:  3ea2e01460.jpg
# Extracting features from image:  1fb1476dd4.jpg
# Extracting features from image:  94ac19189f.jpg
# Extracting features from image:  73d45b4f25.jpg
# Extracting features from image:  400c63b9e5.jpg
# Extracting features from image:  142b723097.jpg
# Extracting features from image:  32eae3eecf.jpg
# Extracting features from image:  7ec7f984fb.jpg
# Extracting features from image:  7c1df0a13a.jpg
# Extracting features from image:  5c5dcd8a22.jpg
# Extracting features from image:  9bf76f7295.jpg
# Extracting features from image:  23d5ae3c7f.jpg
# Extracting features from image:  7fd29911ac.jpg
# Extracting features from image:  9b5fa1d2fe.jpg
# Extracting features from image:  11b7d83354.jpg
# Extracting features from image:  2515fc48ed.jpg
# Extracting features from image:  0f21cda153.jpg
# Extracting features from image:  9640c80f78.jpg
# Extracting features from image:  5b83f6bf2a.jpg
# Extracting features from image:  7da246bc99.jpg
# Extracting features from image:  7d42f0e881.jpg
# Extracting features from image:  0a0b13d222.jpg
# Extracting features from image:  84f8a7d634.jpg
# Extracting features from image:  673a73affb.jpg
# Extracting features from image:  79ce7a27bb.jpg
# Extracting features from image:  5b2e5409d4.jpg
# Extracting features from image:  2f3b46ef06.jpg
# Extracting features from image:  87fd3b8748.jpg
# Extracting features from image:  95f848d627.jpg
# Extracting features from image:  7e81d556d1.jpg
# Extracting features from image:  5d342f46d0.jpg
# Extracting features from image:  7c71d5b549.jpg
# Extracting features from image:  20a162f65c.jpg
# Extracting features from image:  17a29c13f5.jpg
# Extracting features from image:  9ffa8a9f5f.jpg
# Extracting features from image:  9c8612ce65.jpg
# Extracting features from image:  1a99ace1fe.jpg
# Extracting features from image:  177bc31f99.jpg
# Extracting features from image:  20b5171d15.jpg
# Extracting features from image:  8d95dfedfc.jpg
# Extracting features from image:  1fc72e7b9e.jpg
# Extracting features from image:  39f7c2970a.jpg
# Extracting features from image:  64f159e8ff.jpg
# Saving features to h5 file

# %% [markdown]
# **Query using our custom features**

# %%
import numpy as np
import h5py
from skimage import io
from scipy import spatial

# %%
h5f_file = h5py.File("CustomFeatures.h5", 'r')
feats = h5f_file['dataset_1'][:]
image_name = h5f_file['dataset_2'][:]
h5f_file.close()

# %%
image_directory = '/Users/sudipkhadka/Desktop/Data-Science-ML-Engineering/Image-Reterival-System/images'
query_image = io.imread("/Users/sudipkhadka/Desktop/Data-Science-ML-Engineering/Image-Reterival-System/test_image/05768d38ec.jpg")
print("searching for similar image name")

X = extract_features(query_image)
scores = []
for i in range(feats.shape[0]):
    score = 1 - spatial.distance.cosine(X, feats[i])
    scores.append(score)
scores = np.array(scores)
rank_id = np.argsort(scores)[::-1]
rank_score = scores[rank_id]

max_num_matches = 4
lists = [image_name[index] for i, index in enumerate(rank_id[0:max_num_matches])]
print("top %d images in order are:" % max_num_matches, lists)
# Out:
# searching for similar image name
# top 4 images in order are: [b'46d2138807.jpg', b'673a73affb.jpg', b'230d4f00d3.jpg', b'6e66339f51.jpg']

# %%
plt.imshow(query_image)
plt.title('Query image')
plt.show()

# %%
lists = [os.path.join(image_directory, image_name[index].decode('utf-8')) if isinstance(image_name[index], bytes) else os.path.join(image_directory, image_name[index]) 
         for i, index in enumerate(rank_id[0:max_num_matches])]

num_images = len(lists)
fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
for i, image_path in enumerate(lists):
    if os.path.exists(image_path):
        img = mpimg.imread(image_path)  
        axes[i].imshow(img)  
        axes[i].axis('off')  
        axes[i].set_title(f"Image Rank {i+1}")
    else:
        print(f"File not found: {image_path}") 
plt.show()
